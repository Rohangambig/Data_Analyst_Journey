# %%
import pandas as pd

df = pd.read_csv('C:/Users/rohan/OneDrive/Documents/notes/Desktop/Data analyst/Datasets/teachingratings.csv')
df
# Out:
#     minority  age  gender credits    beauty  eval division native tenure  \
# 0        yes   36  female    more  0.289916   4.3    upper    yes    yes
# 1        yes   36  female    more  0.289916   3.7    upper    yes    yes
# 2        yes   36  female    more  0.289916   3.6    upper    yes    yes
# 3        yes   36  female    more  0.289916   4.4    upper    yes    yes
# 4         no   59    male    more -0.737732   4.5    upper    yes    yes
# ..       ...  ...     ...     ...       ...   ...      ...    ...    ...
# 458       no   37    male    more  0.933396   3.5    upper    yes    yes
# 459       no   58  female    more  0.111563   3.5    upper    yes    yes
# 460       no   42    male    more -0.900580   4.0    upper    yes    yes
# 461       no   39    male    more  0.643014   4.3    upper    yes    yes
# 462       no   51  female    more  0.391822   3.0    upper    yes    yes
#
#      students  allstudents  prof  PrimaryLast  vismin  female  single_credit  \
# ...

# %% [markdown]
# ## Pivot tables

# %%
import pandas as pd 

cognizant_data =  pd.read_excel('C:/Users/rohan/OneDrive/Documents/notes/Desktop/Data analyst/Datasets/dataset Cognizant.xlsx')
cognizant_data.head(5)
# Out:
#    Superset ID                                       College Name  \
# 0      5017879  Mangalore Institute of Technology and Engineer...
# 1      5014314  Mangalore Institute of Technology and Engineer...
# 2      5020810  Mangalore Institute of Technology and Engineer...
# 3      5460980  Mangalore Institute of Technology and Engineer...
# 4      5020149  Mangalore Institute of Technology and Engineer...
#
#                   Name                   Email Id          Personal Email Id  \
# 0    Rishal Neha Moras        rishalnia@gmail.com        rishalnia@gmail.com
# 1      Sharan S Shetty      hdksharan99@gmail.com      hdksharan99@gmail.com
# 2  Olivia Carol Dsouza  oliviacdsouza.6@gmail.com  oliviacdsouza.6@gmail.com
# 3          Shravya Rai     shravyarai26@gmail.com     shravyarai26@gmail.com
# 4      Vishal M Shetty  shettyvishal547@gmail.com  shettyvishal547@gmail.com
#
#   Program  Phone Number                                   Course  \
# ...

# %%
cognizant_data.drop(labels=['College Name','Status'],axis=1,inplace=True)

# %%
# cognizant_data.drop(labels='Aptitude Assessment Date & Slot',axis=1,
# inplace=True)
cognizant_data.head(3)
# Out:
#    Superset ID                 Name                   Email Id  \
# 0      5017879    Rishal Neha Moras        rishalnia@gmail.com
# 1      5014314      Sharan S Shetty      hdksharan99@gmail.com
# 2      5020810  Olivia Carol Dsouza  oliviacdsouza.6@gmail.com
#
#            Personal Email Id Program  Phone Number  \
# 0        rishalnia@gmail.com  B.Tech    9481741762
# 1      hdksharan99@gmail.com    B.E.    8277404924
# 2  oliviacdsouza.6@gmail.com    B.E.    6366132014
#
#                                     Course
# 0  Electronics & Communication Engineering
# 1  Electronics & Communication Engineering
# 2           Computer Science & Engineering

# %%
cognizant_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273 entries, 0 to 272
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Superset ID        273 non-null    int64
#  1   Name               273 non-null    object
#  2   Email Id           273 non-null    object
#  3   Personal Email Id  273 non-null    object
#  4   Program            273 non-null    object
#  5   Phone Number       273 non-null    int64
#  6   Course             273 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 15.1+ KB

# %%
pivot_data = cognizant_data.pivot_table(values='Phone Number',index='Program',aggfunc='mean',columns='Superset ID')
pivot_data
# Out:
# Superset ID          5011602       5011603       5011607       5011608  \
# Program
# B.E.            7.795299e+09  7.760791e+09  7.624803e+09  7.411058e+09
# B.E. (Hons.)             NaN           NaN           NaN           NaN
# B.Tech                   NaN           NaN           NaN           NaN
# B.Tech (Hons.)           NaN           NaN           NaN           NaN
#
# Superset ID          5011612       5011613       5011615       5011618  \
# Program
# B.E.            9.164347e+09  8.296442e+09  7.892859e+09  8.296763e+09
# B.E. (Hons.)             NaN           NaN           NaN           NaN
# B.Tech                   NaN           NaN           NaN           NaN
# B.Tech (Hons.)           NaN           NaN           NaN           NaN
#
# Superset ID          5011639       5011652  ...       5468077       5468329  \
# Program                                     ...
# B.E.            7.019563e+09  9.845492e+09  ...  7.624831e+09           NaN
# ...

# %%
# Use  group by class to calculate the number of students who enrolled for each course

programCount = cognizant_data.groupby('Course').size()
programCount
# Out:
# Course
# AI & MACHINE LEARNING                                                           34
# Aeronautical Engineering                                                         1
# Artificial Intelligence                                                          2
# CSE (ARTIFICIAL INTELLIGENCE)                                                    1
# CSE (INTERNET OF THINGS AND CYBER SECURITY INCLUDING BLOCK CHAIN TECHNOLOGY)    29
# Computer Engineering                                                             1
# Computer Network Engineering                                                     1
# Computer Science                                                                12
# Computer Science & Engineering                                                  80
# Computer Science.                                                                1
# Electronics                                                                      1
# ...

# %%
# Ploting the line graph

import matplotlib.pyplot as plt
programCount.plot(kind='line')
plt.xticks(rotation=90,ha='right')
plt.xlabel('Courses')
plt.ylabel('Number of students')
plt.grid(True)
plt.show()

# %%
# plotting the bar graph
import matplotlib.pyplot as plt
programCount.plot(kind='bar')
plt.xticks(rotation=90,ha='right')
plt.xlabel('Courses')
plt.ylabel('Number of students')
plt.grid(True)
plt.show()

# %%
# plotting the histogram graph
import matplotlib.pyplot as plt
programCount.plot(kind='hist')
plt.xticks(rotation=90,ha='right')
plt.xlabel('Courses')
plt.ylabel('Number of students')
plt.grid(True)
plt.show()

# %%
# plotting of group bar chart

program_count = cognizant_data.groupby(['Program','Course'])[['Course','Program']].value_counts()
program_count
# Out:
# Program         Course
# B.E.            AI & MACHINE LEARNING                                                           32
#                 Aeronautical Engineering                                                         1
#                 Artificial Intelligence                                                          2
#                 CSE (ARTIFICIAL INTELLIGENCE)                                                    1
#                 CSE (INTERNET OF THINGS AND CYBER SECURITY INCLUDING BLOCK CHAIN TECHNOLOGY)    29
#                 Computer Engineering                                                             1
#                 Computer Network Engineering                                                     1
#                 Computer Science                                                                11
#                 Computer Science & Engineering                                                  80
# ...
