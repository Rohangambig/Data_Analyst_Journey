# %%
import matplotlib.pyplot as plt
import numpy as np 

x = np.array([1,2,3,4,5])
y = np.sin(x)

plt.plot(x,y)
plt.show()

# %%
import pandas as pd
file_path = 'C:/Users/rohan/OneDrive/Documents/notes/Desktop/Data analyst/Datasets/teachingratings.csv'

df = pd.read_csv(file_path)
df.age.head(10)
# Out:
# 0    36
# 1    36
# 2    36
# 3    36
# 4    59
# 5    59
# 6    59
# 7    51
# 8    51
# 9    40
# Name: age, dtype: int64

# %%
data = pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
plt.bar(data,data.index)
plt.show()

# %%
gender_data =  df.groupby('gender')['age'].median().sort_values(ascending=False)

# %%
gender_data.plot(kind='bar',color='green')
plt.grid(True)
plt.xticks(rotation=45,ha='right')
plt.show()

# %%
non_duplicate = df.drop_duplicates(subset='age')
non_duplicate
# Out:
#     minority  age  gender credits    beauty  eval division native tenure  \
# 0        yes   36  female    more  0.289916   4.3    upper    yes    yes
# 4         no   59    male    more -0.737732   4.5    upper    yes    yes
# 7         no   51    male    more -0.571984   3.7    upper    yes    yes
# 9         no   40  female    more -0.677963   4.3    upper    yes    yes
# 17        no   31  female    more  1.509794   4.4    upper    yes    yes
# 23        no   62    male    more  0.588569   4.2    upper    yes    yes
# 30        no   33  female    more -0.126001   4.0    upper    yes    yes
# 49        no   47    male    more  0.540917   3.9    upper    yes     no
# 59       yes   35    male    more  0.231613   3.1    upper     no    yes
# 62        no   37    male    more -0.066674   4.0    upper    yes     no
# 67        no   42    male    more  0.216892   3.8    upper    yes    yes
# 74        no   49    male    more -0.258696   3.4    upper     no    yes
# ...

# %%
# Use of .sample() function
# Out:
#     minority  age  gender credits    beauty  eval division native tenure  \
# 0        yes   36  female    more  0.289916   4.3    upper    yes    yes
# 1        yes   36  female    more  0.289916   3.7    upper    yes    yes
# 2        yes   36  female    more  0.289916   3.6    upper    yes    yes
# 3        yes   36  female    more  0.289916   4.4    upper    yes    yes
# 4         no   59    male    more -0.737732   4.5    upper    yes    yes
# ..       ...  ...     ...     ...       ...   ...      ...    ...    ...
# 458       no   37    male    more  0.933396   3.5    upper    yes    yes
# 459       no   58  female    more  0.111563   3.5    upper    yes    yes
# 460       no   42    male    more -0.900580   4.0    upper    yes    yes
# 461       no   39    male    more  0.643014   4.3    upper    yes    yes
# 462       no   51  female    more  0.391822   3.0    upper    yes    yes
#
#      students  allstudents  prof  PrimaryLast  vismin  female  single_credit  \
# ...
